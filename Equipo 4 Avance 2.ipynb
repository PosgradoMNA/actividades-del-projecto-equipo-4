# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo-4/blob/main/Equipo%204%20Avance%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Picture1.png](data:image/png;base64,...)
#
# #Rodrigo Rodriguez Rodriguez A01183284
# #Abraham Rincón Treviño A00819677
# #Ciencia y analítica de datos
#
# #Actividad 1: Python for Data Science (IBM)
#
# #Maestría en Inteligencia Artificial Aplicada
# #Presenta:
# #Equipo 2
# #Asesor Tutor:
# #Jobish Vallikavungal Devassia
# #Asesor Titular:
# #Jobish Vallikavungal Devassia
# #23 de septiembre del 2022

# %% [markdown]
# Identificar una metodología que vas a usar durante la realización del proyecto:
#
# *   Usaremos la metodología CRISP-DM WaterfallElemento de lista

# %% [markdown]
# Escribe los pasos estándares en un máximo de 3 oraciones, por cada fase
# CRoss Industry Standard Process for Data Mining (CRISP-DM) es un proceso que sirve para las bases de la data mining. Tiene seis fases:
#
# 1.	Entender el negocio (Business understanding) – ¿Que necesitas del base de datos para el negocio?
# >a.	Se enfoca en entender los objetivos de los datos, así como los requerimientos que queremos obtener, nos sirve para obtener un plan preliminar Bloque con sangría
#
#
# 2.	Entender los datos (Data understanding) –¿Que tenemos y que necesitamos de esto?
# > a.	Comenzamos con la recolección inicial de datos , después nos familiarizamos con los datos entendiendo cada campo, es interesante entender también que sub casos podemos analizar una ves entendiendo esto podemos formular un hipótesisBloque con sangría
#
#
# 3.	Preparación de datos (Data preparation) – ¿Como organizamos los datos para ser modelados?
# > a.Consiste en construir un set de datos apartir de datos crudos sin procesar
